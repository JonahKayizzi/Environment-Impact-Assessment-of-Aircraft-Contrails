# %%
import pandas as pd
import numpy as np
import os
from shapely.geometry import LineString, box
from datetime import datetime, timedelta


class SyntheticFlightsGenerator:
    """Generates synthetic flight paths with dates constrained by station data availability."""

    def __init__(self, stations_file, num_flights=1000, output_dir='data/synthetic_flights'):
        self.stations_file = stations_file
        self.num_flights = num_flights
        self.output_dir = output_dir
        self.stations_df = None
        self.bbox = None

    def load_stations(self):
        """Loads radiosonde stations with date ranges from the filtered CSV file."""
        self.stations_df = pd.read_csv(self.stations_file)
        self.stations_df['start_date'] = pd.to_datetime(
            self.stations_df['date_range'].str.split(' to ').str[0])
        self.stations_df['end_date'] = pd.to_datetime(
            self.stations_df['date_range'].str.split(' to ').str[1])
        lats = self.stations_df['latitude']
        lons = self.stations_df['longitude']
        self.bbox = (lons.min(), lats.min(), lons.max(), lats.max())

    def generate_flight(self):
        """Generates a single synthetic flight with a date within the overlapping data range of departure and arrival stations."""
        dep = self.stations_df.sample(1)
        arr = self.stations_df.sample(1)
        while dep['station_id'].values[0] == arr['station_id'].values[0]:
            arr = self.stations_df.sample(1)
        dep_start = dep['start_date'].values[0]
        dep_end = dep['end_date'].values[0]
        arr_start = arr['start_date'].values[0]
        arr_end = arr['end_date'].values[0]
        overlap_start = max(dep_start, arr_start)
        overlap_end = min(dep_end, arr_end)
        if overlap_start > overlap_end:
            return None  # No overlapping date range
        flight_date = overlap_start + \
            timedelta(days=np.random.randint(
                0, (overlap_end - overlap_start).days))
        dep_lat, dep_lon = dep['latitude'].values[0], dep['longitude'].values[0]
        arr_lat, arr_lon = arr['latitude'].values[0], arr['longitude'].values[0]
        num_points = np.random.randint(5, 10)
        lats = np.linspace(dep_lat, arr_lat, num_points)
        lons = np.linspace(dep_lon, arr_lon, num_points)
        route = list(zip(lats, lons))
        flight_bbox = LineString(route).bounds
        return {
            'departure': dep['station_id'].values[0],
            'arrival': arr['station_id'].values[0],
            'date': flight_date,
            'route': route,
            'bbox': flight_bbox
        }

    def generate_flights(self):
        """Generates multiple synthetic flights with dates and saves them to a CSV file."""
        flights = []
        while len(flights) < self.num_flights:
            flight = self.generate_flight()
            if flight:
                flights.append(flight)
        df = pd.DataFrame(flights)
        os.makedirs(self.output_dir, exist_ok=True)
        df.to_csv(os.path.join(self.output_dir,
                  'synthetic_flights.csv'), index=False)
        with open(os.path.join(self.output_dir, 'flights_bbox.txt'), 'w') as f:
            f.write(
                f"{self.bbox[0]},{self.bbox[1]},{self.bbox[2]},{self.bbox[3]}")
        print(
            f"Synthetic flights saved to '{self.output_dir}/synthetic_flights.csv'")
        print(f"Bounding box saved to '{self.output_dir}/flights_bbox.txt'")

    def run(self):
        """Executes the flight generation process."""
        self.load_stations()
        self.generate_flights()


if __name__ == "__main__":
    stations_file = 'data/european_stations_2010_2025.csv'
    generator = SyntheticFlightsGenerator(stations_file)
    generator.run()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 88
#      86 stations_file = 'data/european_stations_2010_2025.csv'
#      87 generator = SyntheticFlightsGenerator(stations_file)
# ---> 88 generator.run()
#
# Cell In[3], line 82, in SyntheticFlightsGenerator.run(self)
#      80 """Executes the flight generation process."""
#      81 self.load_stations()
# ---> 82 self.generate_flights()
#
# Cell In[3], line 65, in SyntheticFlightsGenerator.generate_flights(self)
#      63 flights = []
#      64 while len(flights) < self.num_flights:
# ---> 65     flight = self.generate_flight()
#      66     if flight:
#      67         flights.append(flight)
#
# Cell In[3], line 32, in SyntheticFlightsGenerator.generate_flight(self)
#      30 """Generates a single synthetic flight with a date within the overlapping data range of departure and arrival stations."""
#      31 dep = self.stations_df.sample(1)
# ---> 32 arr = self.stations_df.sample(1)
#      33 while dep['station_id'].values[0] == arr['station_id'].values[0]:
#      34     arr = self.stations_df.sample(1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:6119, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    6116     weights = sample.preprocess_weights(self, weights, axis)
#    6118 sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
# -> 6119 result = self.take(sampled_indices, axis=axis)
#    6121 if ignore_index:
#    6122     result.index = default_index(len(result))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:4133, in NDFrame.take(self, indices, axis, **kwargs)
#    4128     # We can get here with a slice via DataFrame.__getitem__
#    4129     indices = np.arange(
#    4130         indices.start, indices.stop, indices.step, dtype=np.intp
#    4131     )
# -> 4133 new_data = self._mgr.take(
#    4134     indices,
#    4135     axis=self._get_block_manager_axis(axis),
#    4136     verify=True,
#    4137 )
#    4138 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4139     self, method="take"
#    4140 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\managers.py:894, in BaseBlockManager.take(self, indexer, axis, verify)
#     891 indexer = maybe_convert_indices(indexer, n, verify=verify)
#     893 new_labels = self.axes[axis].take(indexer)
# --> 894 return self.reindex_indexer(
#     895     new_axis=new_labels,
#     896     indexer=indexer,
#     897     axis=axis,
#     898     allow_dups=True,
#     899     copy=None,
#     900 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\managers.py:687, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
# --> 687     new_blocks = [
#     688         blk.take_nd(
#     689             indexer,
#     690             axis=1,
#     691             fill_value=(
#     692                 fill_value if fill_value is not None else blk.fill_value
#     693             ),
#     694         )
#     695         for blk in self.blocks
#     696     ]
#     698 new_axes = list(self.axes)
#     699 new_axes[axis] = new_axis
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\managers.py:688, in <listcomp>(.0)
#     680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
#     687     new_blocks = [
# --> 688         blk.take_nd(
#     689             indexer,
#     690             axis=1,
#     691             fill_value=(
#     692                 fill_value if fill_value is not None else blk.fill_value
#     693             ),
#     694         )
#     695         for blk in self.blocks
#     696     ]
#     698 new_axes = list(self.axes)
#     699 new_axes[axis] = new_axis
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\blocks.py:1307, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1304     allow_fill = True
#    1306 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1307 new_values = algos.take_nd(
#    1308     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1309 )
#    1311 # Called from three places in managers, all of which satisfy
#    1312 #  these assertions
#    1313 if isinstance(self, ExtensionBlock):
#    1314     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1315     #  algos.take_nd call above.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\array_algos\take.py:162, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
# --> 162 func(arr, indexer, out, fill_value)
#     164 if flip_order:
#     165     out = out.T
#
# KeyboardInterrupt:

# %%
import pandas as pd
import numpy as np
import os
from shapely.geometry import LineString, box
from datetime import datetime

# Configuration dictionary for easy customization
CONFIG = {
    'num_flights': 10000,                 # Number of flights to generate
    'min_route_points': 5,            # Minimum number of points in a flight route
    'max_route_points': 10,           # Maximum number of points in a flight route
    'output_dir': './data',           # Directory to save output files
    'stations_file': './data/european_stations_2010_2025.csv',  # Path to stations CSV
    'altitude_variation': 1000,       # Max altitude variation in meters
    'noise_level': 0.01               # Coordinate noise level (degrees)
}


class SyntheticFlightsGenerator:
    """Generates synthetic flight paths with data augmentation for single-station flights."""

    def __init__(self, config):
        self.config = config
        self.stations_df = None
        self.bbox = None

    def load_stations(self):
        """Loads radiosonde stations with exact datetimes from the filtered CSV file."""
        print("Loading stations...")
        self.stations_df = pd.read_csv(self.config['stations_file'])
        self.stations_df['datetime'] = pd.to_datetime(
            self.stations_df['date_range'].str.split(' to ').str[0])
        lats = self.stations_df['latitude']
        lons = self.stations_df['longitude']
        self.bbox = (lons.min(), lats.min(), lons.max(), lats.max())
        print(f"Stations loaded: {len(self.stations_df)} stations found.")

    def generate_flight(self, station, flight_num, total_flights):
        """Generates a single synthetic flight with a loop path and altitude variations for a given station."""
        station_id = station['station_id']
        lat, lon = station['latitude'], station['longitude']
        flight_datetime = station['datetime']
        num_points = np.random.randint(
            self.config['min_route_points'], self.config['max_route_points'] + 1)

        # Create a loop by generating intermediate points around the station
        angles = np.linspace(0, 2 * np.pi, num_points)
        radius = 0.1  # degrees, adjust as needed
        lats = lat + radius * \
            np.sin(
                angles) + np.random.uniform(-self.config['noise_level'], self.config['noise_level'], num_points)
        lons = lon + radius * \
            np.cos(
                angles) + np.random.uniform(-self.config['noise_level'], self.config['noise_level'], num_points)

        # Add altitude variations (in meters)
        altitudes = np.random.uniform(
            0, self.config['altitude_variation'], num_points)
        # Ensure start and end are at ground level (altitude = 0)
        altitudes[0] = 0
        altitudes[-1] = 0

        # Combine lat, lon, and altitude into route points
        route = list(zip(lats, lons, altitudes))
        flight_bbox = LineString([(lon, lat)
                                 for lat, lon, alt in route]).bounds
        print(
            f"Flight {flight_num}/{total_flights} generated for station {station_id} at {flight_datetime}")
        return {
            'station_id': station_id,
            'datetime': flight_datetime,
            'route': route,  # Now includes (lat, lon, altitude)
            'bbox': flight_bbox
        }

    def generate_flights(self):
        """Generates multiple synthetic flights and saves them to a CSV file."""
        print(f"Generating {self.config['num_flights']} flights...")
        flights = []
        for i in range(self.config['num_flights']):
            station = self.stations_df.sample(1).iloc[0]
            flight = self.generate_flight(
                station, i+1, self.config['num_flights'])
            flights.append(flight)
        df = pd.DataFrame(flights)
        print("All flights generated.")
        print("Saving flights to CSV...")
        os.makedirs(self.config['output_dir'], exist_ok=True)
        df.to_csv(os.path.join(
            self.config['output_dir'], 'synthetic_flights.csv'), index=False)
        print(
            f"Flights saved to '{self.config['output_dir']}/synthetic_flights.csv'")
        print("Saving bounding box...")
        with open(os.path.join(self.config['output_dir'], 'flights_bbox.txt'), 'w') as f:
            f.write(
                f"{self.bbox[0]},{self.bbox[1]},{self.bbox[2]},{self.bbox[3]}")
        print(
            f"Bounding box saved to '{self.config['output_dir']}/flights_bbox.txt'")

    def run(self):
        """Executes the flight generation process."""
        print("Starting flight generation...")
        self.load_stations()
        self.generate_flights()
        print("Flight generation completed.")


if __name__ == "__main__":
    generator = SyntheticFlightsGenerator(CONFIG)
    generator.run()
# Out:
# Starting flight generation...
# Loading stations...
# Stations loaded: 9 stations found.
# Generating 10000 flights...
# Flight 1/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 2/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 3/10000 generated for station SPM00008383 at 2018-12-12 00:00:00
# Flight 4/10000 generated for station TUM00017196 at 2016-01-04 12:00:00
# Flight 5/10000 generated for station ITM00016045 at 2016-06-16 18:00:00
# Flight 6/10000 generated for station TUM00017196 at 2016-01-04 12:00:00
# Flight 7/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 8/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 9/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 10/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 11/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 12/10000 generated for station ITM00016546 at 2012-02-28 12:00:00
# Flight 13/10000 generated for station TUM00017196 at 2016-01-04 12:00:00
# Flight 14/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 15/10000 generated for station SPM00008383 at 2018-12-12 00:00:00
# Flight 16/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 17/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 18/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 19/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 20/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 21/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 22/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 23/10000 generated for station ITM00016045 at 2016-06-16 18:00:00
# Flight 24/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 25/10000 generated for station ITM00016045 at 2016-06-16 18:00:00
# Flight 26/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 27/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 28/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 29/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 30/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 31/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 32/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 33/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 34/10000 generated for station ITM00016546 at 2012-02-28 12:00:00
# Flight 35/10000 generated for station ITM00016045 at 2016-06-16 18:00:00
# Flight 36/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 37/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 38/10000 generated for station ITM00016546 at 2012-02-28 12:00:00
# Flight 39/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 40/10000 generated for station ITM00016546 at 2012-02-28 12:00:00
# Flight 41/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 42/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 43/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 44/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 45/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 46/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 47/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 48/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 49/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 50/10000 generated for station TUM00017196 at 2016-01-04 12:00:00
# Flight 51/10000 generated for station SPM00008383 at 2018-12-12 00:00:00
# Flight 52/10000 generated for station SPM00008383 at 2018-12-12 00:00:00
# Flight 53/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 54/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 55/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 56/10000 generated for station ITM00016546 at 2012-02-28 12:00:00
# Flight 57/10000 generated for station SPM00008383 at 2018-12-12 00:00:00
# Flight 58/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 59/10000 generated for station ITM00016546 at 2012-02-28 12:00:00
# Flight 60/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 61/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 62/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 63/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 64/10000 generated for station ITM00016045 at 2016-06-16 18:00:00
# Flight 65/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 66/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 67/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 68/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 69/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 70/10000 generated for station SPM00008383 at 2018-12-12 00:00:00
# Flight 71/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 72/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 73/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 74/10000 generated for station TUM00017196 at 2016-01-04 12:00:00
# Flight 75/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 76/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 77/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 78/10000 generated for station TUM00017196 at 2016-01-04 12:00:00
# Flight 79/10000 generated for station SPM00008383 at 2018-12-12 00:00:00
# Flight 80/10000 generated for station TUM00017196 at 2016-01-04 12:00:00
# Flight 81/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 82/10000 generated for station SPM00008383 at 2018-12-12 00:00:00
# Flight 83/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 84/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 85/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 86/10000 generated for station ITM00016546 at 2012-02-28 12:00:00
# Flight 87/10000 generated for station SPM00008383 at 2018-12-12 00:00:00
# Flight 88/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 89/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 90/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 91/10000 generated for station SPM00008383 at 2018-12-12 00:00:00
# Flight 92/10000 generated for station SPM00008383 at 2018-12-12 00:00:00
# Flight 93/10000 generated for station SPM00008383 at 2018-12-12 00:00:00
# Flight 94/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 95/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 96/10000 generated for station ITM00016045 at 2016-06-16 18:00:00
# Flight 97/10000 generated for station SPM00008383 at 2018-12-12 00:00:00
# Flight 98/10000 generated for station ITM00016045 at 2016-06-16 18:00:00
# Flight 99/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 100/10000 generated for station ITM00016546 at 2012-02-28 12:00:00
# Flight 101/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 102/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 103/10000 generated for station ITM00016045 at 2016-06-16 18:00:00
# Flight 104/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 105/10000 generated for station TUM00017196 at 2016-01-04 12:00:00
# Flight 106/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 107/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 108/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 109/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 110/10000 generated for station TUM00017196 at 2016-01-04 12:00:00
# Flight 111/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 112/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 113/10000 generated for station ITM00016546 at 2012-02-28 12:00:00
# Flight 114/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 115/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 116/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 117/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 118/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 119/10000 generated for station ITM00016045 at 2016-06-16 18:00:00
# Flight 120/10000 generated for station ITM00016045 at 2016-06-16 18:00:00
# Flight 121/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 122/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 123/10000 generated for station ITM00016045 at 2016-06-16 18:00:00
# Flight 124/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 125/10000 generated for station TUM00017196 at 2016-01-04 12:00:00
# Flight 126/10000 generated for station ITM00016546 at 2012-02-28 12:00:00
# Flight 127/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 128/10000 generated for station TUM00017196 at 2016-01-04 12:00:00
# Flight 129/10000 generated for station ITM00016546 at 2012-02-28 12:00:00
# Flight 130/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 131/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 132/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 133/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 134/10000 generated for station TUM00017196 at 2016-01-04 12:00:00
# Flight 135/10000 generated for station ITM00016045 at 2016-06-16 18:00:00
# Flight 136/10000 generated for station TUM00017196 at 2016-01-04 12:00:00
# Flight 137/10000 generated for station SPM00008383 at 2018-12-12 00:00:00
# Flight 138/10000 generated for station ITM00016045 at 2016-06-16 18:00:00
# Flight 139/10000 generated for station TUM00017196 at 2016-01-04 12:00:00
# Flight 140/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 141/10000 generated for station ITM00016045 at 2016-06-16 18:00:00
# Flight 142/10000 generated for station TUM00017196 at 2016-01-04 12:00:00
# Flight 143/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 144/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 145/10000 generated for station SPM00008383 at 2018-12-12 00:00:00
# Flight 146/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 147/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 148/10000 generated for station TUM00017196 at 2016-01-04 12:00:00
# Flight 149/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 150/10000 generated for station TUM00017196 at 2016-01-04 12:00:00
# Flight 151/10000 generated for station ITM00016045 at 2016-06-16 18:00:00
# Flight 152/10000 generated for station TUM00017196 at 2016-01-04 12:00:00
# Flight 153/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 154/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 155/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 156/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 157/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 158/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 159/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 160/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 161/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 162/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 163/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 164/10000 generated for station ITM00016045 at 2016-06-16 18:00:00
# Flight 165/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 166/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 167/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 168/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 169/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 170/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 171/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 172/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 173/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 174/10000 generated for station TUM00017196 at 2016-01-04 12:00:00
# Flight 175/10000 generated for station ITM00016546 at 2012-02-28 12:00:00
# Flight 176/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 177/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 178/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 179/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 180/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 181/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 182/10000 generated for station SPM00008383 at 2018-12-12 00:00:00
# Flight 183/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 184/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 185/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 186/10000 generated for station ITM00016546 at 2012-02-28 12:00:00
# Flight 187/10000 generated for station TUM00017196 at 2016-01-04 12:00:00
# Flight 188/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 189/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 190/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 191/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 192/10000 generated for station ITM00016045 at 2016-06-16 18:00:00
# Flight 193/10000 generated for station SPM00008383 at 2018-12-12 00:00:00
# Flight 194/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 195/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 196/10000 generated for station SPM00008383 at 2018-12-12 00:00:00
# Flight 197/10000 generated for station TUM00017196 at 2016-01-04 12:00:00
# Flight 198/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 199/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 200/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 201/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 202/10000 generated for station ITM00016045 at 2016-06-16 18:00:00
# Flight 203/10000 generated for station ITM00016045 at 2016-06-16 18:00:00
# Flight 204/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 205/10000 generated for station ITM00016045 at 2016-06-16 18:00:00
# Flight 206/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 207/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 208/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 209/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 210/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 211/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 212/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 213/10000 generated for station SPM00008383 at 2018-12-12 00:00:00
# Flight 214/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 215/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 216/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 217/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 218/10000 generated for station RSM00037099 at 2013-12-05 06:00:00
# Flight 219/10000 generated for station GMM00010113 at 2011-06-20 18:00:00
# Flight 220/10000 generated for station ITM00016045 at 2016-06-16 18:00:00
# Flight 221/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 222/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 223/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 224/10000 generated for station ITM00016037 at 2010-01-04 00:00:00
# Flight 225/10000 generated for station TUM00017196 at 2016-01-04 12:00:00
# Flight 226/10000 generated for station NOM00001010 at 2014-11-26 00:00:00
# Flight 227/10000 generated for station UKM00033966 at 2011-01-01 00:00:00
# Flight 228/10000 generated for station SPM00008383 at 2018-12-12 00:00:00
# Flight